# %% [markdown]
# ### Explore ACLED data
#
# A notebook for sharing exploration code for the ACLED data

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import sys
import os 
import io
module_path = os.path.abspath(os.path.join('../src'))
os.chdir(module_path)
sys.path.insert(0, module_path)
from data.utils import *

# %%
kenya_counties = load_data(bucket=BUCKET, path = "BOUNDARIES/ADMIN_1/Africa_bnd_adm1.shp").query("adm0_name == 'Kenya'")
kenya_counties.head()
# Out:
#      OBJECTID iso3        adm1_name adm1_altnm  adm1_id adm0_name  adm0_id  \
# 382      2493  KEN          Baringo        NaN   903882     Kenya      133
# 383      2494  KEN            Bomet        NaN   903883     Kenya      133
# 384      2495  KEN          Bungoma        NaN   903884     Kenya      133
# 385      2496  KEN            Busia        NaN   903885     Kenya      133
# 386      2497  KEN  Elgeyo-Marakwet        NaN   903886     Kenya      133
#
#     mapclr   rb disp_area salb_id        source source_id  source_dat  \
# 382    KEN  RBN        no     NaN  OCHA (ROSEA)     KE030  2018-07-03
# 383    KEN  RBN        no     NaN  OCHA (ROSEA)     KE036  2018-07-03
# 384    KEN  RBN        no     NaN  OCHA (ROSEA)     KE039  2018-07-03
# 385    KEN  RBN        no     NaN  OCHA (ROSEA)     KE040  2018-07-03
# 386    KEN  RBN        no     NaN  OCHA (ROSEA)     KE028  2018-07-03
#
#      lst_update  validity  shape_Leng  shape_Area        ucode  \
# 382  2023-01-16         0    5.932315    0.884732  KEN_0001_V1
# 383  2023-01-16         0    2.922220    0.198099  KEN_0002_V1
# 384  2023-01-16         0    3.058455    0.244211  KEN_0003_V1
# 385  2023-01-16         0    2.641988    0.145977  KEN_0004_V1
# 386  2023-01-16         0    3.888933    0.244432  KEN_0005_V1
#
#                                               geometry
# 382  POLYGON ((35.78390 1.65557, 35.78496 1.65554, ...
# 383  POLYGON ((35.47360 -0.39920, 35.47845 -0.40663...
# 384  POLYGON ((34.62385 1.09989, 34.62463 1.09907, ...
# 385  POLYGON ((34.36734 0.77358, 34.36814 0.77290, ...
# 386  POLYGON ((35.69818 1.28225, 35.69788 1.27905, ...

# %%
kenya_counties.plot(column = "shape_Area")

# %%
df = load_data(BUCKET, "CONFLICT/ACLED_data_Africa_Ucodes.csv").reset_index()
df.head()
# Out:
#    OID_ event_id_cnty        event_date  year  time_precision  \
# 0     1      BFO11038  17 November 2023  2023               1
# 1     2      BFO11043  17 November 2023  2023               1
# 2     3      MLI31293  17 November 2023  2023               1
# 3     4      MLI31299  17 November 2023  2023               1
# 4     5      MLI31314  17 November 2023  2023               1
#
#             disorder_type                  event_type  \
# 0      Political violence  Violence against civilians
# 1  Strategic developments      Strategic developments
# 2      Political violence  Explosions/Remote violence
# 3      Political violence                     Battles
# 4      Political violence  Violence against civilians
#
#                  sub_event_type                                        actor1  \
# 0                        Attack  JNIM: Group for Support of Islam and Muslims
# 1  Looting/property destruction  JNIM: Group for Support of Islam and Muslims
# 2              Air/drone strike              Military Forces of Niger (2023-)
# 3                   Armed clash  JNIM: Group for Support of Islam and Muslims
# 4                        Attack               Military Forces of Mali (2021-)
#
#   assoc_actor_1  ...                       source         source_scale  \
# 0           NaN  ...         BurkinaWeb; Facebook   New media-National
# 1           NaN  ...           Undisclosed Source  Local partner-Other
# 2           NaN  ...  Twitter; Undisclosed Source  Local partner-Other
# 3           NaN  ...           Undisclosed Source  Local partner-Other
# 4  Wagner Group  ...                      Twitter            New media
#
#                                                notes  fatalities  tags  \
# 0  On 17 November 2023, JNIM militants killed fiv...           5   NaN
# 1  Looting: On 17 November 2023, JNIM militants s...           0   NaN
# 2  On 17 November 2023, likely Nigerien forces ca...           3   NaN
# 3  On 17 November 2023, JNIM militants attacked a...           3   NaN
# 4  On 17 November 2023, Wagner mercenaries arrest...           0   NaN
#
#     timestamp  ucode_level0 ucode_level1      ucode_level2   ucode
# 0  1700524094        BFA_V1  BFA_0001_V1  BFA_0001_0003_V1  BFA_V1
# 1  1700524094        BFA_V1  BFA_0008_V1  BFA_0008_0005_V1  BFA_V1
# 2  1700524094        MLI_V1  MLI_0002_V1  MLI_0002_0004_V1  MLI_V1
# 3  1700524094        MLI_V1  MLI_0007_V1  MLI_0007_0003_V1  MLI_V1
# 4  1700524094        MLI_V1  MLI_0004_V1  MLI_0004_0002_V1  MLI_V1
#
# [5 rows x 36 columns]
